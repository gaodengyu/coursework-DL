# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-x121_22g
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-x121_22g
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=fecf01994f23b1d4509b8abc94a3671f3bb853cc9f8d3ce688eb4639b8c2d205
#   Stored in directory: /tmp/pip-ephem-wheel-cache-diu4rhwg/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x).relu()
    h2 = self.linear2(h1).relu()
    h3 = self.linear3(h2).relu()
    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.725744, train error 70.10,  val loss 1.750619, percent error 71.10
# Epoch     1, train loss 1.441346, train error 56.10,  val loss 1.538265, percent error 61.50
# Epoch     2, train loss 1.225925, train error 45.30,  val loss 1.387501, percent error 55.00
# Epoch     3, train loss 1.057867, train error 39.42,  val loss 1.272739, percent error 50.90
# Epoch     4, train loss 0.915630, train error 34.03,  val loss 1.220698, percent error 47.10
# Epoch     5, train loss 0.754846, train error 26.07,  val loss 1.145587, percent error 44.50
# Epoch     6, train loss 0.661742, train error 23.75,  val loss 1.116838, percent error 42.10
# Epoch     7, train loss 0.570559, train error 20.72,  val loss 1.102066, percent error 40.50
# Epoch     8, train loss 0.516691, train error 18.80,  val loss 1.109192, percent error 39.70
# Epoch     9, train loss 0.463949, train error 16.22,  val loss 1.151344, percent error 41.60
# Epoch    10, train loss 0.387362, train error 13.10,  val loss 1.210123, percent error 39.90
# Epoch    11, train loss 0.355225, train error 11.88,  val loss 1.118992, percent error 35.80
# Epoch    12, train loss 0.282323, train error 9.72,  val loss 1.158893, percent error 37.20
# Epoch    13, train loss 0.217989, train error 6.93,  val loss 1.217438, percent error 35.50
# Epoch    14, train loss 0.169326, train error 4.88,  val loss 1.298001, percent error 35.60
# Epoch    15, train loss 0.208563, train error 6.97,  val loss 1.442122, percent error 38.30
# Epoch    16, train loss 0.238558, train error 7.85,  val loss 1.390698, percent error 37.30
# Epoch    17, train loss 0.228139, train error 8.28,  val loss 1.385046, percent error 36.80
# Epoch    18, train loss 0.196741, train error 7.12,  val loss 1.426047, percent error 37.00
# Epoch    19, train loss 0.115727, train error 3.28,  val loss 1.373884, percent error 35.80
# Epoch    20, train loss 0.044638, train error 0.50,  val loss 1.312550, percent error 33.20
# Epoch    21, train loss 0.020793, train error 0.00,  val loss 1.329327, percent error 31.70
# Epoch    22, train loss 0.014507, train error 0.00,  val loss 1.351064, percent error 31.10
# Epoch    23, train loss 0.011699, train error 0.00,  val loss 1.392221, percent error 30.80
# Epoch    24, train loss 0.009807, train error 0.00,  val loss 1.415856, percent error 30.70
# Epoch    25, train loss 0.008683, train error 0.00,  val loss 1.440775, percent error 30.90
# Epoch    26, train loss 0.007709, train error 0.00,  val loss 1.464234, percent error 30.90
# Epoch    27, train loss 0.007019, train error 0.00,  val loss 1.485331, percent error 31.30
# Epoch    28, train loss 0.006376, train error 0.00,  val loss 1.501813, percent error 31.50
# Epoch    29, train loss 0.005874, train error 0.00,  val loss 1.521513, percent error 31.30
# Epoch    30, train loss 0.005487, train error 0.00,  val loss 1.539694, percent error 31.30
# Epoch    31, train loss 0.005077, train error 0.00,  val loss 1.549043, percent error 31.20
# Epoch    32, train loss 0.004757, train error 0.00,  val loss 1.563515, percent error 31.00
# Epoch    33, train loss 0.004475, train error 0.00,  val loss 1.575860, percent error 30.90
# Epoch    34, train loss 0.004221, train error 0.00,  val loss 1.588569, percent error 30.80
# Epoch    35, train loss 0.004021, train error 0.00,  val loss 1.600891, percent error 31.20
# Epoch    36, train loss 0.003807, train error 0.00,  val loss 1.614939, percent error 31.30
# Epoch    37, train loss 0.003632, train error 0.00,  val loss 1.622439, percent error 31.00
# Epoch    38, train loss 0.003451, train error 0.00,  val loss 1.633414, percent error 31.20
# Epoch    39, train loss 0.003299, train error 0.00,  val loss 1.645477, percent error 31.20
# Epoch    40, train loss 0.003221, train error 0.00,  val loss 1.648862, percent error 31.00
# Epoch    41, train loss 0.003152, train error 0.00,  val loss 1.654253, percent error 31.20
# Epoch    42, train loss 0.003086, train error 0.00,  val loss 1.658165, percent error 31.20
# Epoch    43, train loss 0.003025, train error 0.00,  val loss 1.664378, percent error 31.10
# Epoch    44, train loss 0.002968, train error 0.00,  val loss 1.668301, percent error 31.30
# Epoch    45, train loss 0.002907, train error 0.00,  val loss 1.673223, percent error 31.30
# Epoch    46, train loss 0.002852, train error 0.00,  val loss 1.677393, percent error 31.40
# Epoch    47, train loss 0.002801, train error 0.00,  val loss 1.682624, percent error 31.40
# Epoch    48, train loss 0.002749, train error 0.00,  val loss 1.686109, percent error 31.40
# Epoch    49, train loss 0.002699, train error 0.00,  val loss 1.691636, percent error 31.50
# Epoch    50, train loss 0.002652, train error 0.00,  val loss 1.695136, percent error 31.40
# Epoch    51, train loss 0.002606, train error 0.00,  val loss 1.699489, percent error 31.60
# Epoch    52, train loss 0.002560, train error 0.00,  val loss 1.704164, percent error 31.60
# Epoch    53, train loss 0.002516, train error 0.00,  val loss 1.708371, percent error 31.50
# Epoch    54, train loss 0.002474, train error 0.00,  val loss 1.711757, percent error 31.40
# Epoch    55, train loss 0.002434, train error 0.00,  val loss 1.715209, percent error 31.40
# Epoch    56, train loss 0.002396, train error 0.00,  val loss 1.719499, percent error 31.50
# Epoch    57, train loss 0.002357, train error 0.00,  val loss 1.723104, percent error 31.70
# Epoch    58, train loss 0.002319, train error 0.00,  val loss 1.726532, percent error 31.70
# Epoch    59, train loss 0.002283, train error 0.00,  val loss 1.730723, percent error 31.60
# Epoch    60, train loss 0.002265, train error 0.00,  val loss 1.732318, percent error 31.60
# Epoch    61, train loss 0.002248, train error 0.00,  val loss 1.734110, percent error 31.60
# Epoch    62, train loss 0.002231, train error 0.00,  val loss 1.736231, percent error 31.70
# Epoch    63, train loss 0.002214, train error 0.00,  val loss 1.737824, percent error 31.70
# Epoch    64, train loss 0.002197, train error 0.00,  val loss 1.739332, percent error 31.80
# Epoch    65, train loss 0.002181, train error 0.00,  val loss 1.741392, percent error 31.80
# Epoch    66, train loss 0.002165, train error 0.00,  val loss 1.742928, percent error 31.70
# Epoch    67, train loss 0.002149, train error 0.00,  val loss 1.744993, percent error 31.80
# Epoch    68, train loss 0.002134, train error 0.00,  val loss 1.746352, percent error 31.80
# Epoch    69, train loss 0.002118, train error 0.00,  val loss 1.748003, percent error 31.80
# Epoch    70, train loss 0.002103, train error 0.00,  val loss 1.749986, percent error 31.80
# Epoch    71, train loss 0.002089, train error 0.00,  val loss 1.751513, percent error 31.80
# Epoch    72, train loss 0.002074, train error 0.00,  val loss 1.753129, percent error 31.80
# Epoch    73, train loss 0.002059, train error 0.00,  val loss 1.754988, percent error 31.80
# Epoch    74, train loss 0.002045, train error 0.00,  val loss 1.756172, percent error 31.80
# Epoch    75, train loss 0.002031, train error 0.00,  val loss 1.758186, percent error 31.80
# Epoch    76, train loss 0.002017, train error 0.00,  val loss 1.759750, percent error 31.80
# Epoch    77, train loss 0.002003, train error 0.00,  val loss 1.761222, percent error 31.80
# Epoch    78, train loss 0.001990, train error 0.00,  val loss 1.762661, percent error 31.80
# Epoch    79, train loss 0.001976, train error 0.00,  val loss 1.764492, percent error 31.90
# Epoch    80, train loss 0.001970, train error 0.00,  val loss 1.765325, percent error 31.80
# Epoch    81, train loss 0.001962, train error 0.00,  val loss 1.765935, percent error 31.80
# Epoch    82, train loss 0.001956, train error 0.00,  val loss 1.766742, percent error 31.90
# Epoch    83, train loss 0.001950, train error 0.00,  val loss 1.767455, percent error 31.90
# Epoch    84, train loss 0.001943, train error 0.00,  val loss 1.768276, percent error 31.90
# Epoch    85, train loss 0.001937, train error 0.00,  val loss 1.769020, percent error 32.00
# Epoch    86, train loss 0.001930, train error 0.00,  val loss 1.769986, percent error 31.90
# Epoch    87, train loss 0.001924, train error 0.00,  val loss 1.770744, percent error 31.90
# Epoch    88, train loss 0.001918, train error 0.00,  val loss 1.771400, percent error 31.90
# Epoch    89, train loss 0.001911, train error 0.00,  val loss 1.772103, percent error 32.00
# Epoch    90, train loss 0.001905, train error 0.00,  val loss 1.772887, percent error 31.90
# Epoch    91, train loss 0.001899, train error 0.00,  val loss 1.773753, percent error 31.90
# Epoch    92, train loss 0.001893, train error 0.00,  val loss 1.774688, percent error 32.00
# Epoch    93, train loss 0.001887, train error 0.00,  val loss 1.775306, percent error 32.00
# Epoch    94, train loss 0.001881, train error 0.00,  val loss 1.776005, percent error 32.00
# Epoch    95, train loss 0.001875, train error 0.00,  val loss 1.776799, percent error 32.00
# Epoch    96, train loss 0.001869, train error 0.00,  val loss 1.777355, percent error 32.00
# Epoch    97, train loss 0.001863, train error 0.00,  val loss 1.778187, percent error 32.00
# Epoch    98, train loss 0.001857, train error 0.00,  val loss 1.778903, percent error 32.00
# Epoch    99, train loss 0.001851, train error 0.00,  val loss 1.780044, percent error 32.00

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
